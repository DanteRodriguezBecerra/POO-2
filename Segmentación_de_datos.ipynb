# %%
estudiantes = {"Palafox":[1,2,3,4,5],
       "Edu":[6,7,8,9,1],
       "Zamora":[1,3,5,7,9],
       "Eli":[2,4,6,8,0],
       "Diego":[1,2,4,5,7]}
type(estudiantes)
# Out:
# dict

# %% [markdown]
# Creamos un diccionario donde podemos crear una base de datos

# %%
import pandas as pd

df_estudiantes = pd.DataFrame(estudiantes)
df_estudiantes
# Out:
#    Palafox  Edu  Zamora  Eli  Diego
# 0        1    6       1    2      1
# 1        2    7       3    4      2
# 2        3    8       5    6      4
# 3        4    9       7    8      5
# 4        5    1       9    0      7

# %% [markdown]
# Las API son mecanismos que permiten a dos componentes de software comunicarse entre sí mediante un conjunto de definiciones y protocolos. Por ejemplo, el sistema de software del instituto de meteorología contiene datos meteorológicos diarios.[API](https://aws.amazon.com/es/what-is/api/#:~:text=Las%20API%20son%20mecanismos%20que,meteorolog%C3%ADa%20contiene%20datos%20meteorol%C3%B3gicos%20diarios.)

# %%
import yfinance as yf

# %%
ticker = " AAPL"

aapl = yf.download(ticker, start = "2020-01-01", end = "2024-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed
